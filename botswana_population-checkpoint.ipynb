# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/pdata.csv')

# %%
data
# Out:
#     settlement   total   males  females  19-cast-votes  female  Youth
# 0     Gaborone  246325  118727   127598          80320   30321  50398
# 1  Francistown  103417   49647    53770          61232   41350  37567
# 2       Serowe   55676   25846    29830          40413   22222  16165
# 3      Palapye   52636   25891    26745          14003   54102   5181
# 4    Mahalapye   48431   22984    25447          26239   12032  11545
# 5        Kanye   48028   22273    25755          18301    9003  14099
# 6      Mochudi   50317   23716    26601          21872   50323   8093
# 7   Molepolole   74674   34436    40238          36751   23999  16538
# 8         Maun   84993   41083    43910          24945   11195  20406

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   settlement     9 non-null      object
#  1   total          9 non-null      int64
#  2   males          9 non-null      int64
#  3   females        9 non-null      int64
#  4   19-cast-votes  9 non-null      int64
#  5   female         9 non-null      int64
#  6   Youth          9 non-null      int64
# dtypes: int64(6), object(1)
# memory usage: 632.0+ bytes

# %%
data.plot(x="settlement", y="total", kind="bar")
plt.show()

# %%
data.plot(kind='bar',
        x='settlement',
        y=["females", "males", "Youth"])
 

 
# set the title
plt.title('velocity vs Time')

# show the plot
plt.show()

# %%
palapye = [ '1994' , '1999' , '2004' , '2009' ,
        '2014' , '2019' , '2022' ]
  
# Create a list of data to be 
# represented in y-axis
population = [ 10670 , 12011 , 18530 , 21570 ,
            29000 , 39180 , 55063 ]
  
# Create a dataframe using the two lists
df_palapye_population = pd.DataFrame(
    { 'palapye' : palapye , 'population' : population })
  
df_palapye_population
# Out:
#   palapye  population
# 0    1994       10670
# 1    1999       12011
# 2    2004       18530
# 3    2009       21570
# 4    2014       29000
# 5    2019       39180
# 6    2022       55063

# %%
df_palapye_population.plot( 'palapye' , 'population' )
# Out:
# <AxesSubplot:xlabel='palapye'>

# %%
sns.regplot(x= 'total', y = 'males', data=data)
# Out:
# <AxesSubplot:xlabel='total', ylabel='males'>

# %%
sns.regplot(x= 'total', y = 'females', data=data)
# Out:
# <AxesSubplot:xlabel='total', ylabel='females'>

# %%
lri = LinearRegression()
lri.fit(data[['total']].values, data.malesS)
# Out:
# LinearRegression()

# %%
lri.predict([[5000]])
# Out:
# array([1759.81616551])

# %%
data.plot(x="settlement", y="19-cast-votes", kind="bar")
plt.show()

# %%
from numpy import exp, array, random, dot

class NeuralNetwork():
    def __init__(self):
        # Seed the random number generator, so it generates the same numbers
        # every time the program runs.
        random.seed(1)

        # We model a single neuron, with 6 input connections and 1 output connection.
        # We assign random weights to a 6 x 1 matrix, with values in the range -1 to 1
        # and mean 0.
        self.synaptic_weights = 2 * random.random((6, 1)) - 1

    # The Sigmoid function, which describes an S shaped curve.
    # We pass the weighted sum of the inputs through this function to
    # normalise them between 0 and 1.
    def __sigmoid(self, x):
        return 1 / (1 + exp(-x))

    # The derivative of the Sigmoid function.
    # This is the gradient of the Sigmoid curve.
    # It indicates how confident we are about the existing weight.
    def __sigmoid_derivative(self, x):
        return x * (1 - x)

    # train the neural network through a process of trial and error.
    # Adjusting the synaptic weights each time.
    def train(self, training_set_inputs, training_set_outputs, number_of_training_iterations):
        for iteration in range(1000):
            # Pass the training set through our neural network (a single neuron).
            output = self.think(training_set_inputs)

            # Calculate the error (The difference between the desired output
            # and the predicted output).
            error = training_set_outputs - output

            # Multiply the error by the input and again by the gradient of the Sigmoid curve.
            # This means less confident weights are adjusted more.
            # This means inputs, which are zero, do not cause changes to the weights.
            adjustment = dot(training_set_inputs.T, error * self.__sigmoid_derivative(output))

            # Adjust the weights.
            self.synaptic_weights += adjustment

    # The neural network thinks.
    def think(self, inputs):
        # Pass inputs through our neural network (our single neuron).
        return self.__sigmoid(dot(inputs, self.synaptic_weights))


if __name__ == "__main__":

    #Intialise a single neuron neural network.
    neural_network = NeuralNetwork()

    print ("Random starting synaptic weights: ")
    print (neural_network.synaptic_weights)

    # The training set. We have 4 examples, each consisting of 3 input values
    # and 1 output value.
    training_set_inputs = array([[12, 10, 5, 20, 20, 1], [0, 0, 1, 0, 0, 1], [6, 0, 1, 7, 0, 1], [0, 7, 1, 3, 3, 1], [200, 0, 1, 20, 0, 1], [30, 300, 1, 20, 20, 1]])
    training_set_outputs = array([[0, 0, 1, 0, 1, 1]]).T

    # Train the neural network using a training set.
    # Do it 100 times and make small adjustments each time.
    neural_network.train(training_set_inputs, training_set_outputs, 1000)
    print ("New synaptic weights after training: ")
    print (neural_network.synaptic_weights)

    # Test the neural network with a new situation.
    print ("Considering new situation [5001, 1300, 190, 2001, 100, 177] -> ?: ")
    print (neural_network.think(array([100, 30, 100, 0, 30, 0])))
# Out:
# Random starting synaptic weights:
# [[-0.16595599]
#  [ 0.44064899]
#  [-0.99977125]
#  [-0.39533485]
#  [-0.70648822]
#  [-0.81532281]]
# New synaptic weights after training:
# [[ 2.27552216]
#  [-0.01173035]
#  [-2.17191794]
#  [-0.17569477]
#  [-1.09360878]
#  [-1.9382802 ]]
# Considering new situation [5001, 1300, 190, 2001, 100, 177] -> ?:
# [1.2536996e-10]

# %% [raw]
# data_dict = {'Year': [2,2 , 1, 2, 4, 3],
#              'time': [0, 10, 20, 30, 40, 50],
#              'Velocity1': [10, 14, 25, 26, 35, 40],
#              'Velocity2': [13, 23, 23, 31, 33, 42],
#              'Velocity3': [6, 19, 21, 26, 30, 36]
#              }
#
# # creating a data frame object
# df = pd.DataFrame(data_dict)
# data_dict

# %%
df.plot(kind='scatter',
        x='time',
        y='Velocity1',
        color='red')
 
# set the title
plt.title('ScatterPlot')
 
# show the plot
plt.show()

# %%
ax = plt.gca()
# line plot for math marks
df.plot(kind='line',
        x='time',
        y='Velocity1',
        color='green', ax=ax)
 
# line plot for physics marks
df.plot(kind='line', x='time',
        y='Velocity2',
        color='blue', ax=ax)
 
# line plot for chemistry marks
df.plot(kind='line', x='time',
        y='Velocity3',
        color='black', ax=ax)
 
# set the title
plt.title('velocity vs Time')

# show the plot
plt.show()

# %%
import numpy as np
array = np.array(df['time'])
array
# Out:
# 10
